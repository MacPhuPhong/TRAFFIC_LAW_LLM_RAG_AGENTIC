# %% [markdown]
# # 05 — RQ5: Prompt engineering
#
# **Câu hỏi:** Với cùng retriever + generator model, prompt nào cho câu trả lời chính xác + bám citation tốt nhất?
#
# **Biến thể prompt:**
# 1. `P0_zero_shot` — chỉ instruction thuần
# 2. `P1_few_shot` — 3 ví dụ Q→A có citation
# 3. `P2_cot` — chain-of-thought ("Suy luận từng bước rồi trả lời")
# 4. `P3_citation_forced` — bắt buộc format `[Điều X, Khoản Y — doc_id]` cho mỗi claim
# 5. `P4_refuse_when_no_context` — thêm rule từ chối nếu chunks thiếu
#
# **Metric:** F1, ROUGE-L, citation precision/recall, refusal rate trên câu out_of_scope.

# %%
# --- Setup ---
import sys
from pathlib import Path

HERE = Path.cwd()
# Walk up to find traffic_rag/ (works when run from anywhere under it)
for p in [HERE] + list(HERE.parents):
    if (p / "source").is_dir() and (p / "research").is_dir():
        TRAFFIC_RAG = p
        break
else:
    raise RuntimeError("Could not locate traffic_rag/ root")

sys.path.insert(0, str(TRAFFIC_RAG))
sys.path.insert(0, str(TRAFFIC_RAG.parent))  # so `research.utils` works

from research.utils.langsmith_setup import enable_tracing
enable_tracing(project="traffic-rag-research", run_name="rq5-prompt")

EVAL_PATH = TRAFFIC_RAG / "research" / "data" / "eval_qa.jsonl"
RESULTS_DIR = TRAFFIC_RAG / "research" / "results" / "metrics"
FIGURES_DIR = TRAFFIC_RAG / "research" / "results" / "figures"
RESULTS_DIR.mkdir(parents=True, exist_ok=True)
FIGURES_DIR.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## 1. Định nghĩa 5 prompt variant

# %%
PROMPTS = {
    "P0_zero_shot": "TODO",
    "P1_few_shot": "TODO",
    "P2_cot": "TODO",
    "P3_citation_forced": "TODO",
    "P4_refuse_when_no_context": "TODO",
}

# %% [markdown]
# ## 2. Chạy eval set với mỗi prompt

# %%
# TODO: monkey-patch LegalAnswerGenerator.system_prompt hoặc dùng subclass
# rồi chạy run_over_dataset cho từng prompt

# %% [markdown]
# ## 3. Tính citation precision/recall

# %%
from research.utils.metrics import citation_precision_recall
# TODO: parse citations từ answer text (regex cho format `[Điều X, Khoản Y — doc_id]`)
# so sánh với gold_citations

# %% [markdown]
# ## Kết luận
#
# _TODO: prompt nào win trên câu thường vs câu out_of_scope._
